# %% [markdown]
# # 1. Formulación del problema

# %%
# Clase abstracta
class Problem:
    def __init__(self, initial, goal):
        self.initial = initial # Estado inicial
        self.goal = goal # Meta

    def actions(self, state):
        raise NotImplementedError

    # Función de transición
    def result(self, state, action):
        raise NotImplementedError

    # Función de desempeño
    def is_goal(self, state):
        return self.goal == state

    def action_cost(self, state1, action, state2):
        return 1

    def h(self, state):
        return 0

# %%
class GraphProblem(Problem):
    def __init__(self, initial, goal, graph):
        super().__init__(initial, goal)
        self.graph = graph

    def actions(self, state):
        lista = []
        for key in self.graph[state].keys():
            lista.append(key)
        return lista

    # Función de transición
    def result(self, state, action):
        return action

    def action_cost(self, state1, action, state2):
        return self.graph[state1][state2]

# %% [markdown]
# #Grafo del metro de la Ciudad de México con unidades unitarias

# %%
metro_cdmx = {
    # --- Línea 1 ---
    'Observatorio': {'Tacubaya': 1},
    'Tacubaya': {'Observatorio': 1, 'Juanacatlan': 1, 'Tacuba': 1, 'Constituyentes': 1, 'San Pedro de los Pinos': 1, 'Patriotismo': 1},
    'Juanacatlan': {'Tacubaya': 1, 'Chapultepec': 1},
    'Chapultepec': {'Juanacatlan': 1, 'Sevilla': 1},
    'Sevilla': {'Chapultepec': 1, 'Insurgentes': 1},
    'Insurgentes': {'Sevilla': 1, 'Cuauhtemoc': 1},
    'Cuauhtemoc': {'Insurgentes': 1, 'Balderas': 1},
    'Balderas': {'Cuauhtemoc': 1, 'Salto del Agua': 1, 'Juarez': 1, 'Ninos Heroes': 1},
    'Salto del Agua': {'Balderas': 1, 'Isabel la Catolica': 1, 'San Juan de Letran': 1, 'Doctores': 1},
    'Isabel la Catolica': {'Salto del Agua': 1, 'Pino Suarez': 1},
    'Pino Suarez': {'Isabel la Catolica': 1, 'Merced': 1, 'Zocalo/Tenochtitlan': 1, 'San Antonio Abad': 1},
    'Merced': {'Pino Suarez': 1, 'Candelaria': 1},
    'Candelaria': {'Merced': 1, 'San Lazaro': 1, 'Morelos': 1, 'Fray Servando': 1},
    'San Lazaro': {'Candelaria': 1, 'Moctezuma': 1, 'R. Flores Magon': 1, 'Morelos': 1},
    'Moctezuma': {'San Lazaro': 1, 'Balbuena': 1},
    'Balbuena': {'Moctezuma': 1, 'Boulevard Puerto Aereo': 1},
    'Boulevard Puerto Aereo': {'Balbuena': 1, 'Gomez Farias': 1},
    'Gomez Farias': {'Boulevard Puerto Aereo': 1, 'Zaragoza': 1},
    'Zaragoza': {'Gomez Farias': 1, 'Pantitlan': 1},
    'Pantitlan': {'Zaragoza': 1, 'Hangares': 1, 'Puebla': 1, 'Agricola Oriental': 1},

    # --- Línea 2 ---
    'Cuatro Caminos': {'Panteones': 1},
    'Panteones': {'Cuatro Caminos': 1, 'Tacuba': 1},
    'Tacuba': {'Panteones': 1, 'Cuitlahuac': 1, 'Refineria': 1, 'San Joaquin': 1},
    'Cuitlahuac': {'Tacuba': 1, 'Popotla': 1},
    'Popotla': {'Cuitlahuac': 1, 'Colegio Militar': 1},
    'Colegio Militar': {'Popotla': 1, 'Normal': 1},
    'Normal': {'Colegio Militar': 1, 'San Cosme': 1},
    'San Cosme': {'Normal': 1, 'Revolucion': 1},
    'Revolucion': {'San Cosme': 1, 'Hidalgo': 1},
    'Hidalgo': {'Revolucion': 1, 'Bellas Artes': 1, 'Guerrero': 1, 'Juarez': 1},
    'Bellas Artes': {'Hidalgo': 1, 'Allende': 1, 'Garibaldi/Lagunilla': 1, 'San Juan de Letran': 1},
    'Allende': {'Bellas Artes': 1, 'Zocalo/Tenochtitlan': 1},
    'Zocalo/Tenochtitlan': {'Allende': 1, 'Pino Suarez': 1},
    'San Antonio Abad': {'Pino Suarez': 1, 'Chabacano': 1},
    'Chabacano': {'San Antonio Abad': 1, 'Viaducto': 1, 'Obrera': 1, 'La Viga': 1, 'Lazaro Cardenas': 1, 'Jamaica': 1},
    'Viaducto': {'Chabacano': 1, 'Xola': 1},
    'Xola': {'Viaducto': 1, 'Villa de Cortes': 1},
    'Villa de Cortes': {'Xola': 1, 'Nativitas': 1},
    'Nativitas': {'Villa de Cortes': 1, 'Portales': 1},
    'Portales': {'Nativitas': 1, 'Ermita': 1},
    'Ermita': {'Portales': 1, 'General Anaya': 1, 'Eje Central': 1, 'Mexicaltzingo': 1},
    'General Anaya': {'Ermita': 1, 'Taxqueña': 1},
    'Taxqueña': {'General Anaya': 1},

    # --- Línea 3 ---
    'Indios Verdes': {'Deportivo 18 de Marzo': 1},
    'Deportivo 18 de Marzo': {'Indios Verdes': 1, 'Potrero': 1, 'Lindavista': 1, 'La Villa-Basilica': 1},
    'Potrero': {'Deportivo 18 de Marzo': 1, 'La Raza': 1},
    'La Raza': {'Potrero': 1, 'Tlatelolco': 1, 'Autobuses del Norte': 1, 'Misterios': 1},
    'Tlatelolco': {'La Raza': 1, 'Guerrero': 1},
    'Guerrero': {'Tlatelolco': 1, 'Hidalgo': 1, 'Garibaldi/Lagunilla': 1, 'Buenavista': 1},
    'Juarez': {'Hidalgo': 1, 'Balderas': 1},
    'Ninos Heroes': {'Balderas': 1, 'Hospital General': 1},
    'Hospital General': {'Ninos Heroes': 1, 'Centro Medico': 1},
    'Centro Medico': {'Hospital General': 1, 'Etiopia/Plaza de la Transparencia': 1, 'Chilpancingo': 1, 'Lazaro Cardenas': 1},
    'Etiopia/Plaza de la Transparencia': {'Centro Medico': 1, 'Eugenia': 1},
    'Eugenia': {'Etiopia/Plaza de la Transparencia': 1, 'Division del Norte': 1},
    'Division del Norte': {'Eugenia': 1, 'Zapata': 1},
    'Zapata': {'Division del Norte': 1, 'Coyoacan': 1, 'Hospital 20 de Noviembre': 1, 'Parque de los Venados': 1},
    'Coyoacan': {'Zapata': 1, 'Viveros/Derechos Humanos': 1},
    'Viveros/Derechos Humanos': {'Coyoacan': 1, 'Miguel Angel de Quevedo': 1},
    'Miguel Angel de Quevedo': {'Viveros/Derechos Humanos': 1, 'Copilco': 1},
    'Copilco': {'Miguel Angel de Quevedo': 1, 'Universidad': 1},
    'Universidad': {'Copilco': 1},

    # --- Línea 4 ---
    'Martin Carrera': {'Talisman': 1, 'La Villa-Basilica': 1},
    'Talisman': {'Martin Carrera': 1, 'Bondojito': 1},
    'Bondojito': {'Talisman': 1, 'Consulado': 1},
    'Consulado': {'Bondojito': 1, 'Canal del Norte': 1, 'Valle Gomez': 1, 'Eduardo Molina': 1},
    'Canal del Norte': {'Consulado': 1, 'Morelos': 1},
    'Morelos': {'Canal del Norte': 1, 'Candelaria': 1, 'San Lazaro': 1, 'Tepito': 1},
    'Fray Servando': {'Candelaria': 1, 'Jamaica': 1},
    'Jamaica': {'Fray Servando': 1, 'Santa Anita': 1, 'Chabacano': 1, 'Mixiuhca': 1},
    'Santa Anita': {'Jamaica': 1, 'La Viga': 1, 'Coyuya': 1},

    # --- Línea 5 ---
    'Politecnico': {'Instituto del Petroleo': 1},
    'Instituto del Petroleo': {'Politecnico': 1, 'Autobuses del Norte': 1, 'Vallejo': 1, 'Lindavista': 1},
    'Autobuses del Norte': {'Instituto del Petroleo': 1, 'La Raza': 1},
    'Misterios': {'La Raza': 1, 'Valle Gomez': 1},
    'Valle Gomez': {'Misterios': 1, 'Consulado': 1},
    'Eduardo Molina': {'Consulado': 1, 'Aragon': 1},
    'Aragon': {'Eduardo Molina': 1, 'Oceania': 1},
    'Oceania': {'Aragon': 1, 'Terminal Aerea': 1, 'Deportivo Oceania': 1, 'Romero Rubio': 1},
    'Terminal Aerea': {'Oceania': 1, 'Hangares': 1},
    'Hangares': {'Terminal Aerea': 1, 'Pantitlan': 1},

    # --- Línea 6 ---
    'El Rosario': {'Tezozomoc': 1, 'Aquiles Serdan': 1},
    'Tezozomoc': {'El Rosario': 1, 'Azcapotzalco': 1},
    'Azcapotzalco': {'Tezozomoc': 1, 'Ferreria/Arena Ciudad de Mexico': 1},
    'Ferreria/Arena Ciudad de Mexico': {'Azcapotzalco': 1, 'Norte 45': 1},
    'Norte 45': {'Ferreria/Arena Ciudad de Mexico': 1, 'Vallejo': 1},
    'Vallejo': {'Norte 45': 1, 'Instituto del Petroleo': 1},
    'Lindavista': {'Instituto del Petroleo': 1, 'Deportivo 18 de Marzo': 1},
    'La Villa-Basilica': {'Deportivo 18 de Marzo': 1, 'Martin Carrera': 1},

    # --- Línea 7 ---
    'Aquiles Serdan': {'El Rosario': 1, 'Camarones': 1},
    'Camarones': {'Aquiles Serdan': 1, 'Refineria': 1},
    'Refineria': {'Camarones': 1, 'Tacuba': 1},
    'San Joaquin': {'Tacuba': 1, 'Polanco': 1},
    'Polanco': {'San Joaquin': 1, 'Auditorio': 1},
    'Auditorio': {'Polanco': 1, 'Constituyentes': 1},
    'Constituyentes': {'Auditorio': 1, 'Tacubaya': 1},
    'San Pedro de los Pinos': {'Tacubaya': 1, 'San Antonio': 1},
    'San Antonio': {'San Pedro de los Pinos': 1, 'Mixcoac': 1},
    'Mixcoac': {'San Antonio': 1, 'Barranca del Muerto': 1, 'Insurgentes Sur': 1},
    'Barranca del Muerto': {'Mixcoac': 1},

    # --- Línea 8 ---
    'Garibaldi/Lagunilla': {'Bellas Artes': 1, 'Lagunilla': 1, 'Guerrero': 1},
    'San Juan de Letran': {'Bellas Artes': 1, 'Salto del Agua': 1},
    'Doctores': {'Salto del Agua': 1, 'Obrera': 1},
    'Obrera': {'Doctores': 1, 'Chabacano': 1},
    'La Viga': {'Chabacano': 1, 'Santa Anita': 1},
    'Coyuya': {'Santa Anita': 1, 'Iztacalco': 1},
    'Iztacalco': {'Coyuya': 1, 'Apatlaco': 1},
    'Apatlaco': {'Iztacalco': 1, 'Aculco': 1},
    'Aculco': {'Apatlaco': 1, 'Escuadron 201': 1},
    'Escuadron 201': {'Aculco': 1, 'Atlalilco': 1},
    'Atlalilco': {'Escuadron 201': 1, 'Iztapalapa': 1, 'Mexicaltzingo': 1, 'Culhuacan': 1},
    'Iztapalapa': {'Atlalilco': 1, 'Cerro de la Estrella': 1},
    'Cerro de la Estrella': {'Iztapalapa': 1, 'UAM-I': 1},
    'UAM-I': {'Cerro de la Estrella': 1, 'Constitucion de 1917': 1},
    'Constitucion de 1917': {'UAM-I': 1},

    # --- Línea 9 ---
    'Patriotismo': {'Tacubaya': 1, 'Chilpancingo': 1},
    'Chilpancingo': {'Patriotismo': 1, 'Centro Medico': 1},
    'Lazaro Cardenas': {'Centro Medico': 1, 'Chabacano': 1},
    'Mixiuhca': {'Jamaica': 1, 'Velodromo': 1},
    'Velodromo': {'Mixiuhca': 1, 'Ciudad Deportiva': 1},
    'Ciudad Deportiva': {'Velodromo': 1, 'Puebla': 1},
    'Puebla': {'Ciudad Deportiva': 1, 'Pantitlan': 1},

    # --- Línea A ---
    'Agricola Oriental': {'Pantitlan': 1, 'Canal de San Juan': 1},
    'Canal de San Juan': {'Agricola Oriental': 1, 'Tepalcates': 1},
    'Tepalcates': {'Canal de San Juan': 1, 'Guelatao': 1},
    'Guelatao': {'Tepalcates': 1, 'Penon Viejo': 1},
    'Penon Viejo': {'Guelatao': 1, 'Acatitla': 1},
    'Acatitla': {'Penon Viejo': 1, 'Santa Marta': 1},
    'Santa Marta': {'Acatitla': 1, 'Los Reyes': 1},
    'Los Reyes': {'Santa Marta': 1, 'La Paz': 1},
    'La Paz': {'Los Reyes': 1},

    # --- Línea B ---
    'Ciudad Azteca': {'Plaza Aragon': 1},
    'Plaza Aragon': {'Ciudad Azteca': 1, 'Olimpica': 1},
    'Olimpica': {'Plaza Aragon': 1, 'Ecatepec': 1},
    'Ecatepec': {'Olimpica': 1, 'Muzquiz': 1},
    'Muzquiz': {'Ecatepec': 1, 'Rio de los Remedios': 1},
    'Rio de los Remedios': {'Muzquiz': 1, 'Impulsora': 1},
    'Impulsora': {'Rio de los Remedios': 1, 'Nezahualcoyotl': 1},
    'Nezahualcoyotl': {'Impulsora': 1, 'Villa de Aragon': 1},
    'Villa de Aragon': {'Nezahualcoyotl': 1, 'Bosque de Aragon': 1},
    'Bosque de Aragon': {'Villa de Aragon': 1, 'Deportivo Oceania': 1},
    'Deportivo Oceania': {'Bosque de Aragon': 1, 'Oceania': 1},
    'Romero Rubio': {'Oceania': 1, 'R. Flores Magon': 1},
    'R. Flores Magon': {'Romero Rubio': 1, 'San Lazaro': 1},
    'Tepito': {'Morelos': 1, 'Lagunilla': 1},
    'Lagunilla': {'Tepito': 1, 'Garibaldi/Lagunilla': 1},
    'Buenavista': {'Guerrero': 1},

    # --- Línea 12 ---
    'Insurgentes Sur': {'Mixcoac': 1, 'Hospital 20 de Noviembre': 1},
    'Hospital 20 de Noviembre': {'Insurgentes Sur': 1, 'Zapata': 1},
    'Parque de los Venados': {'Zapata': 1, 'Eje Central': 1},
    'Eje Central': {'Parque de los Venados': 1, 'Ermita': 1},
    'Mexicaltzingo': {'Ermita': 1, 'Atlalilco': 1},
    'Culhuacan': {'Atlalilco': 1, 'San Andres Tomatlan': 1},
    'San Andres Tomatlan': {'Culhuacan': 1, 'Lomas Estrella': 1},
    'Lomas Estrella': {'San Andres Tomatlan': 1, 'Calle 11': 1},
    'Calle 11': {'Lomas Estrella': 1, 'Periferico Oriente': 1},
    'Periferico Oriente': {'Calle 11': 1, 'Tezonco': 1},
    'Tezonco': {'Periferico Oriente': 1, 'Olivos': 1},
    'Olivos': {'Tezonco': 1, 'Nopalera': 1},
    'Nopalera': {'Olivos': 1, 'Zapotitlan': 1},
    'Zapotitlan': {'Nopalera': 1, 'Tlaltenco': 1},
    'Tlaltenco': {'Zapotitlan': 1, 'Tlahuac': 1},
    'Tlahuac': {'Tlaltenco': 1}
}

# %%
class Node:
    def __init__(self, state, parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def path(self):
        lista_path = []
        node = self
        while node:
            lista_path.append(node.state)
            node = node.parent
        return lista_path[::-1]

    def expand(self, problem):
        lista = []
        for action in problem.actions(self.state):
            lista.append(self.child_node(problem, action))
        return lista

    def child_node(self, problem, action):
        next_state = problem.result(self.state, action)
        step_cost = problem.action_cost(self.state, action, next_state)
        return Node(next_state, self, action, self.path_cost + step_cost)

# %%
def depth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = [start_node]
    explored = set()

    while frontier:
        node = frontier.pop()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
from collections import deque

def breadth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = deque([start_node])
    explored = set()

    while frontier:
        node = frontier.popleft()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %% [markdown]
# #Caso 1: Cuatro Caminos a Pantitlán
# Misma ruta en ambos algoritmos

# %%
problem = GraphProblem("Cuatro Caminos", "Pantitlan", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquin',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Medico',
#  'Lazaro Cardenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velodromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlan']

# %%
problem = GraphProblem("Cuatro Caminos", "Pantitlan", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquin',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Medico',
#  'Lazaro Cardenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velodromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlan']

# %% [markdown]
# #Segundo caso: Politecnico a Taxqueña
# Por anchura da una ruta más corta que por profundidad

# %%
problem = GraphProblem("Politecnico", "Taxqueña", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Politecnico',
#  'Instituto del Petroleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basilica',
#  'Martin Carrera',
#  'Talisman',
#  'Bondojito',
#  'Consulado',
#  'Eduardo Molina',
#  'Aragon',
#  'Oceania',
#  'Romero Rubio',
#  'R. Flores Magon',
#  'San Lazaro',
#  'Morelos',
#  'Tepito',
#  'Lagunilla',
#  'Garibaldi/Lagunilla',
#  'Guerrero',
#  'Hidalgo',
#  'Juarez',
#  'Balderas',
#  'Ninos Heroes',
#  'Hospital General',
#  'Centro Medico',
#  'Lazaro Cardenas',
#  'Chabacano',
#  'Jamaica',
#  'Santa Anita',
#  'Coyuya',
#  'Iztacalco',
#  'Apatlaco',
#  'Aculco',
#  'Escuadron 201',
#  'Atlalilco',
#  'Mexicaltzingo',
#  'Ermita',
#  'General Anaya',
#  'Taxqueña']

# %%
problem = GraphProblem("Politecnico", "Taxqueña", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Politecnico',
#  'Instituto del Petroleo',
#  'Autobuses del Norte',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Hidalgo',
#  'Bellas Artes',
#  'Allende',
#  'Zocalo/Tenochtitlan',
#  'Pino Suarez',
#  'San Antonio Abad',
#  'Chabacano',
#  'Viaducto',
#  'Xola',
#  'Villa de Cortes',
#  'Nativitas',
#  'Portales',
#  'Ermita',
#  'General Anaya',
#  'Taxqueña']

# %% [markdown]
# #Tercer caso: Zapata a Oceanía
# Por profundidad da una ruta más corta que por anchura

# %%
problem = GraphProblem("Zapata", "Oceania", metro_cdmx)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'Parque de los Venados',
#  'Eje Central',
#  'Ermita',
#  'Mexicaltzingo',
#  'Atlalilco',
#  'Escuadron 201',
#  'Aculco',
#  'Apatlaco',
#  'Iztacalco',
#  'Coyuya',
#  'Santa Anita',
#  'La Viga',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velodromo',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlan',
#  'Hangares',
#  'Terminal Aerea',
#  'Oceania']

# %%
problem = GraphProblem("Zapata", "Oceania", metro_cdmx)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'Division del Norte',
#  'Eugenia',
#  'Etiopia/Plaza de la Transparencia',
#  'Centro Medico',
#  'Lazaro Cardenas',
#  'Chabacano',
#  'Jamaica',
#  'Fray Servando',
#  'Candelaria',
#  'San Lazaro',
#  'R. Flores Magon',
#  'Romero Rubio',
#  'Oceania']
